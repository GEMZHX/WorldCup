# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import pandas as pd
import numpy as np
import time

# %%
limitstarts = range(0, 1000, 50)

# %%
tables = []
for limitstart in limitstarts:
    my_url = 'http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=' \
                + str(limitstart)
    print(my_url)
    time.sleep(2)
    #opening the connection and grabbing the content
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()

    page_soup = soup(page_html, "html.parser")

    table = page_soup.findAll('table')[2]

    new_table = pd.DataFrame(columns=range(0,7), index=np.arange(51))

    row_marker = 0
    for row in table.find_all('tr'):
        column_marker = 0
        columns = row.find_all('td')
        for column in columns:
            new_table.iat[row_marker,column_marker] = column.get_text()
            column_marker += 1
        if row_marker == 0:
            new_table.columns = new_table.loc[0,:]
        row_marker += 1
    new_table.drop([0], inplace =True)
    new_table.head()
    tables.append(new_table)
# Out:
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=0
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=50
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=100
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=150
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=200
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=250
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=300
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=350
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=400
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=450
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=500
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=550
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=600
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=650
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=700
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=750
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=800
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=850
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=900
# http://www.soccer-db.info/index.php?option=com_php&views=php&Itemid=224&team1=0&team2=0&tour=all&limitstart=950

# %%
new_table = pd.concat(tables, ignore_index=True)
new_table
# Out:
# 0          Date                           Venue  \
# 0    2018-06-22           St Petersburg, Russia
# 1    2018-06-22             Kaliningrad, Russia
# 2    2018-06-22               Volgograd, Russia
# 3    2018-06-21         Nizhny Novgorod, Russia
# 4    2018-06-21            Ekaterinburg, Russia
# 5    2018-06-21                  Samara, Russia
# 6    2018-06-20           Rostov-on-Don, Russia
# 7    2018-06-20                  Moscow, Russia
# 8    2018-06-20                   Kazan, Russia
# 9    2018-06-19           St Petersburg, Russia
# 10   2018-06-19                 Saransk, Russia
# 11   2018-06-19                  Moscow, Russia
# 12   2018-06-18         Nizhny Novgorod, Russia
# 13   2018-06-18                   Sochi, Russia
# 14   2018-06-18               Volgograd, Russia
# 15   2018-06-17           Rostov-on-Don, Russia
# 16   2018-06-17                  Moscow, Russia
# 17   2018-06-17                  Samara, Russia
# 18   2018-06-16                  Moscow, Russia
# 19   2018-06-16             Kaliningrad, Russia
# 20   2018-06-16                   Kazan, Russia
# 21   2018-06-16                 Saransk, Russia
# 22   2018-06-15                   Sochi, Russia
# 23   2018-06-15            Ekaterinburg, Russia
# 24   2018-06-15           St Petersburg, Russia
# 25   2018-06-14                  Moscow, Russia
# 26   2018-06-12              Innsbruck, Austria
# 27   2018-06-12                  Warsaw, Poland
# 28   2018-06-11                 Grödig, Austria
# 29   2018-06-11               Brussels, Belgium
# ..          ...                             ...
# 970  2017-05-31            Abidjan, Ivory Coast
# 971  2017-05-31                 Agadir, Morocco
# 972  2017-05-31                   Empoli, Italy
# 973  2017-05-28      Los Angeles, United States
# 974  2017-05-28       Washington, United States
# 975  2017-05-28                   Lautoka. Fiji
# 976  2017-05-25                    Accra, Ghana
# 977  2017-05-25                      Suva, Fiji
# 978  2017-05-21                  Cotonou, Benin
# 979  2017-05-17          Les Abymes, Guadeloupe
# 980  2017-05-13                    Cairo, Egypt
# 981  2017-05-11                  Dakar, Senegal
# 982  2017-05-07  Basseterre, St Kitts and Nevis
# 988  2018 qualifying comp. (final round)  Details»
# 989  2018 qualifying comp. (final round)  Details»
# 990  2018 qualifying comp. (final round)  Details»
# 991  2018 qualifying comp. (final round)  Details»
# 992  2018 qualifying comp. (final round)  Details»
# 993  2018 qualifying comp. (final round)  Details»
# 994  2018 qualifying comp. (final round)  Details»
# 995  2018 qualifying comp. (final round)  Details»
# 996  2018 qualifying comp. (final round)  Details»
# 997  2018 qualifying comp. (final round)  Details»
# 998  2018 qualifying comp. (final round)  Details»
# 999  2018 qualifying comp. (final round)  Details»
#
# [1000 rows x 7 columns]

# %%
new_table.drop(['Season', 'Link'], axis = 1, inplace=True)
new_table.head()
# Out:
# 0        Date                    Venue                     Match Score  \
# 0  2018-06-22    St Petersburg, Russia   \nBrazil - Costa Rica\n   2:0
# 1  2018-06-22      Kaliningrad, Russia  \nSerbia - Switzerland\n   1:2
# 2  2018-06-22        Volgograd, Russia     \nNigeria - Iceland\n   2:0
# 3  2018-06-21  Nizhny Novgorod, Russia   \nArgentina - Croatia\n   0:3
# 4  2018-06-21     Ekaterinburg, Russia         \nFrance - Peru\n   1:0
#
# 0      Tournament
# 0  FIFA World Cup
# 1  FIFA World Cup
# 2  FIFA World Cup
# 3  FIFA World Cup
# 4  FIFA World Cup

# %%
new_table['Home'] = new_table['Match'].apply(lambda x: x.split(' - ')[0][1:])
new_table['Away'] = new_table['Match'].apply(lambda x: x.split(' - ')[1][:-1])
new_table.drop(['Match'], axis = 1, inplace = True)
new_table['Venue'] = new_table['Venue'].apply(lambda x: x.split(', ')[1] if ',' in x else x)
new_table['Home_score'] = new_table['Score'].apply(lambda x: int(x.split(':')[0]))
new_table['Away_score'] = new_table['Score'].apply(lambda x: int(x.split(':')[1]))
new_table.drop(['Score'], axis = 1, inplace = True)
new_table['is_win'] = new_table['Home_score'] - new_table['Away_score']

def win_draw_lose(x):
    if x > 0:
        return 'Win'
    elif x < 0:
        return 'Lose'
    else:
        return 'Draw'

new_table['is_win'] = new_table['is_win'].apply(win_draw_lose)
new_table.head()
# Out:
# 0        Date   Venue      Tournament       Home         Away  Home_score  \
# 0  2018-06-22  Russia  FIFA World Cup     Brazil   Costa Rica           2
# 1  2018-06-22  Russia  FIFA World Cup     Serbia  Switzerland           1
# 2  2018-06-22  Russia  FIFA World Cup    Nigeria      Iceland           2
# 3  2018-06-21  Russia  FIFA World Cup  Argentina      Croatia           0
# 4  2018-06-21  Russia  FIFA World Cup     France         Peru           1
#
# 0  Away_score is_win
# 0           0    Win
# 1           2   Lose
# 2           0    Win
# 3           3   Lose
# 4           0    Win

# %%
new_table['Date'] = pd.to_datetime(new_table['Date'])

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# Date          1000 non-null datetime64[ns]
# Venue         1000 non-null object
# Tournament    1000 non-null object
# Home          1000 non-null object
# Away          1000 non-null object
# Home_score    1000 non-null int64
# Away_score    1000 non-null int64
# is_win        1000 non-null object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 62.6+ KB
